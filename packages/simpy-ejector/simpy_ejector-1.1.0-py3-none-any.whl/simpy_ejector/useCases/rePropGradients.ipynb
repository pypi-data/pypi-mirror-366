# %%
import sys
sys.path.append("../") 
import refProp
# %matplotlib notebook

# %%
RP = refProp.setup('butane')

# %%
vals = refProp.densityDerivativesTest(RP, p = 1e3)

# %% [markdown]
# the Density derivatives dDdh and dDdp have discontinuity by the phase transition line
