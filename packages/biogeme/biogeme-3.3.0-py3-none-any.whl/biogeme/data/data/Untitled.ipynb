# %%
import pandas as pd

# %%
df = pd.read_csv('optima.dat', sep='\t')

# %%
df
# Out:
#             ID  DestAct  NbTransf  TimePT  WalkingTimePT  WaitingTimePT  \
# 0     10350017        2         4      85             23             10
# 1     10350020        1         4     108             26             16
# 2     10350025       11         2      82             33              5
# 3     10350075        1         3     107             21             31
# 4     10350085        1         5     190            116             18
# ...        ...      ...       ...     ...            ...            ...
# 2260  96040535        1         6     299             84             94
# 2261  96040537        8         0     139            116              0
# 2262  96040537        8         0      71             57              0
# 2263  96040538       11         2     118             70             10
# 2264  96040538        1         3     140             53             23
#
#       CostPT  CostCar  TimeCar  NbHousehold  ...  FreqTripHouseh  Region  \
# ...

# %%
specific_id = 96040538
row = specific_row = df[df['ID'] == specific_id]
row
# Out:
#             ID  DestAct  NbTransf  TimePT  WalkingTimePT  WaitingTimePT  \
# 2263  96040538       11         2     118             70             10
# 2264  96040538        1         3     140             53             23
#
#       CostPT  CostCar  TimeCar  NbHousehold  ...  FreqTripHouseh  Region  \
# 2263    11.4     1.77       24            5  ...               4       7
# 2264    12.6     2.23       28            5  ...               4       7
#
#       distance_km  Choice  InVehicleTime  ModeToSchool  ReportedDuration  \
# 2263         17.5       1             38             3                30
# 2264         20.0       1             64             3                40
#
#       CoderegionCAR  age    Weight
# 2263              7   49  0.000409
# 2264              7   49  0.000409
#
# [2 rows x 117 columns]
